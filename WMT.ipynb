# %%
import netCDF4 as nc
from pathlib import Path
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib as mpl
import matplotlib.path as mpath
import cartopy.feature as cfeature
import cmocean

# %%
data=xr.open_dataset("D:\\ihespdata\\xiliangdiao\\AAA.nc")
A = data.sigma_wmt

# %%
###### loading and computations for isobath transport ##########
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
net_offshore10 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2010.nc')
## load experiment + take mean in time
net_offshore20 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2020.nc')
## load experiment + take mean in time
net_offshore30 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2030.nc')
## load experiment + take mean in time
net_offshore40 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2040.nc')
## load experiment + take mean in time
net_offshore50 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2050.nc')
## load experiment + take mean in time
net_offshore60 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2060.nc')
## load experiment + take mean in time
net_offshore70 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2070.nc')
## load experiment + take mean in time
net_offshore80 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2080.nc')
## load experiment + take mean in time
net_offshore90 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2090.nc')
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
net_offshore1850 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_1850.nc')

# %%
def DSW_transport_full(ax):
    #ax.plot(data2.mea,A,color = 'k',linestyle = ':', linewidth = 2, label = '1850')
    #ax.plot(net_offshore18,data.isopycnal_bins,color = 'k', linestyle = ':', linewidth = 2, label = '1850')
    #ax.plot(net_offshore1860,data.isopycnal_bins,color = 'darkred', linestyle = ':', linewidth = 2, label = '1860')
    ax.plot(net_offshore1850.mea,A,color = 'k', linestyle = ':', linewidth = 2, label = '1850')
    
    ax.plot(net_offshore10.mea,A ,color = 'k', linewidth = 2, label = '2010')
    ax.plot(net_offshore20.mea,A , color = 'darkred', linewidth = 2, label = '2020')
    ax.plot(net_offshore30.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
    
    ax.plot(net_offshore40.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
    ax.plot(net_offshore50.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
    ax.plot(net_offshore60.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
    ax.plot(net_offshore70.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
    ax.plot(net_offshore80.mea,A ,color = 'blue', linestyle = '-.', label = '2080')
    ax.plot(net_offshore90.mea,A ,color = 'darkred', linestyle = '-.', label = '2090')
    
    ax.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 35)
    ax.set_xlabel('Surface water mass transformation on the Antarctic shelf (Sv)', fontsize = 30)
    ax.plot([0,0],[30,33],'k',linewidth=0.5)
    ax.set_xticks([-1,0,1,2,3,4,5,6,7,8])
    ax.set_xticklabels(['-1','0','1','2','3','4','5','6','7','8'], fontsize = 28)
    ax.set_yticks([31.4,31.5,31.6,31.7,31.8,31.9,32.0,32.1,32.2,32.3,32.4,32.5,32.6,32.7,32.8,32.9,33])
    ax.set_yticklabels(['31.4','31.5','31.6','31.7','31.8','31.9','32.0','32.1','32.2','32.3','32.4','32.5','32.6','32.7','32.8','32.9','33.0'], fontsize = 28)
    ax.set_xlim((-2,9))
    ax.set_ylim((33,31.6))
    ax.plot([-3,13],[32.57, 32.57],'k',linewidth=3)
    ax.plot([-3,13],[32.37, 32.37],'k',linewidth=3)
    
    ax.text(7.5,32.68, 'DSW', fontsize = 28, color = 'purple')
    ax.text(7.5,32.50, 'CDW', fontsize = 28, color = 'tomato')    
    ax.text(7.4,32.3, 'AASW', fontsize = 28, color = 'royalblue') 
    ax.legend(fontsize = 16)

# %%
from matplotlib import gridspec
import matplotlib.colors as col
import matplotlib.path as mpath
import cartopy.crs as ccrs
fig = plt.figure(figsize=(20,30), dpi=100)
ax0 = fig.add_axes([0.1, 0.5, 0.6, 0.36])
DSW_transport_full(ax0)
plt.savefig("WMT.png",bbox_inches='tight')
