# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns

# %%
ave1 = np.loadtxt("C:\\Users\\xilia\\Downloads\\second-paper-6-10-main\\ave1.out")
ave2 = np.loadtxt("C:\\Users\\xilia\\Downloads\\second-paper-6-10-main\\ave2.out")

ave1ave1 = np.loadtxt("C:\\Users\\xilia\\Downloads\\second-paper-6-10-main\\ave1ave1.out")
ave2ave2 = np.loadtxt("C:\\Users\\xilia\\Downloads\\second-paper-6-10-main\\ave2ave2.out")

# %%
pwd
# Out:
# 'C:\\Users\\xilia\\Downloads\\second-paper-6-10-main'

# %%
my_font = {'fontname':'Cambria', 'size':'20'}
bwith =400
##################################################################
fig = plt.figure(figsize=(20,15), dpi=100)
################################################################
################################################################

ax1 = fig.add_axes([0.1, 0.9, 0.8, 0.37],
                   xticklabels=[])

#ax0 = plt.subplot(2,1,1)
ax1.plot(ave2,'black',linewidth=5,label='HR-PI' )
ax1.plot(ave1,'red',linewidth=5,label='HR-TN')

#plt.hlines(mean, 0, 3000, colors = "red",linestyles = "dashed")
#plt.vlines(1866, -1, 2.4, colors = "black",linestyles = "dashed",linewidth=3)
#ax0.fill_between(t,mean,-ww2,where=-ww2 < 0,facecolor='red', alpha=1)
#########################################
plt.xticks(range(0,251,50), ['(HR-PI year)','300','350','400','450', '500'],**my_font,color='black')
plt.vlines(156, 33.8,34.8, colors = "black",linestyles = "dashed",linewidth=3)
ax1=plt.gca();#获得坐标轴的句柄
ax1.spines['bottom'].set_linewidth(2);###设置底部坐标轴的粗细
ax1.spines['left'].set_linewidth(2);####设置左边坐标轴的粗细
ax1.spines['right'].set_linewidth(2);###设置右边坐标轴的粗细
ax1.spines['top'].set_linewidth(2);###设置右边坐标轴的粗细
#plt.xticks(range(0,2952,240), ['250','270','290','310','330', '350', '370','390','410','430','450', '470', '490','510','430','450','470','490','500'],**my_font)
plt.yticks(**my_font)
#plt.xlabel('Years',**my_font)
#plt.xlabel('Years',**my_font)
plt.ylabel('Salinity (psu)',color= 'black',**my_font)
plt.axis("tight")
#plt.hlines(0, 0, 4200, colors = "g",linestyles = "dashed")
ax1.set(ylim=(33.75,34.8),xlim=(0, 250))
#ax1.text(0.02, 0.05, '(a)', transform=ax1.transAxes,size=26, weight='bold')
plt.legend(loc='lower left',fontsize='xx-large')
ax1.text(0.12, 0.05, '(a) Weddell Sea', transform=ax1.transAxes,size=45, weight='bold')

################################################333
ax2 = fig.add_axes([0.1, 0.5, 0.8, 0.37],
                   xticklabels=[])

#ax0 = plt.subplot(2,1,1)
ax2.plot(ave2ave2,'black',linewidth=5,label='HR-PI' )
ax2.plot(ave1ave1,'red',linewidth=5,label='HR-TN')

#plt.hlines(mean, 0, 3000, colors = "red",linestyles = "dashed")
#plt.vlines(1866, -1, 2.4, colors = "black",linestyles = "dashed",linewidth=3)
#ax0.fill_between(t,mean,-ww2,where=-ww2 < 0,facecolor='red', alpha=1)
#########################################
#plt.xticks(**my_font)

#plt.xticks(range(0,250,50), ['(HR-TN year)','1900','1950','2000','2050'],**my_font,color='red')
#ax2.set_xticks(range(0,251,50))
ax2.set_xticklabels(['(HR-TN year)','1900','1950','2000','2050', '2100', '1970','1990','2010','2030','2050', '2070', '2090'],**my_font,color='red')
plt.vlines(156, 33.8,34.8, colors = "black",linestyles = "dashed",linewidth=3)
ax2=plt.gca();#获得坐标轴的句柄
ax2.spines['bottom'].set_linewidth(2);###设置底部坐标轴的粗细
ax2.spines['left'].set_linewidth(2);####设置左边坐标轴的粗细
ax2.spines['right'].set_linewidth(2);###设置右边坐标轴的粗细
ax2.spines['top'].set_linewidth(2);###设置右边坐标轴的粗细
#plt.xticks(range(0,2952,240), ['250','270','290','310','330', '350', '370','390','410','430','450', '470', '490','510','430','450','470','490','500'],**my_font)
plt.yticks(**my_font)
#plt.xlabel('Years',**my_font)
#plt.xlabel('Years',**my_font)
plt.ylabel('Salinity (psu)',color= 'black',**my_font)
plt.axis("tight")
#plt.hlines(0, 0, 4200, colors = "g",linestyles = "dashed")
ax2.set(ylim=(33.75,34.8),xlim=(0, 250))
#ax1.text(0.02, 0.05, '(a)', transform=ax1.transAxes,size=26, weight='bold')
plt.legend(loc='lower left',fontsize='xx-large')
ax2.text(0.12, 0.05, '(b) Ross Sea', transform=ax2.transAxes,size=45, weight='bold')
plt.savefig("WSsaltline222.png",bbox_inches='tight')
# Out:
# C:\Users\xilia\AppData\Local\Temp\ipykernel_13616\1365228942.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(['(HR-TN year)','1900','1950','2000','2050', '2100', '1970','1990','2010','2030','2050', '2070', '2090'],**my_font,color='red')
