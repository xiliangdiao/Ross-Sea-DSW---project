# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
from matplotlib.colors import from_levels_and_colors
import numpy as np
from matplotlib import animation
from matplotlib.colors import BoundaryNorm
import matplotlib.colors as cols
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
from matplotlib import ticker, cm
import seaborn as sns
import xarray as xr

# %%
mea2060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\mea2060.out")

meaFQ2060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaFQ2060.out")

meaQ2060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaQ2060.out")

meaF12060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF12060.out")

meaF22060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF22060.out")

meaF32060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF32060.out")

meaF452060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF452060.out")

meaF672060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF672060.out")

meaF772060 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF772060.out")

# %%
mea2010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\mea2010.out")

meaFQ2010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaFQ2010.out")

meaQ2010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaQ2010.out")

meaF12010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF12010.out")

meaF22010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF22010.out")

meaF32010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF32010.out")

meaF452010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF452010.out")

meaF672010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF672010.out")

meaF772010 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF772010.out")

# %%
mea2020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\mea2020.out")

meaFQ2020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaFQ2020.out")

meaQ2020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaQ2020.out")

meaF12020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF12020.out")

meaF22020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF22020.out")

meaF32020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF32020.out")

meaF452020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF452020.out")

meaF672020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF672020.out")

meaF772020 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF772020.out")

# %%
mea2030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\mea2030.out")

meaFQ2030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaFQ2030.out")

meaQ2030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaQ2030.out")

meaF12030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF12030.out")

meaF22030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF22030.out")

meaF32030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF32030.out")

meaF452030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF452030.out")

meaF672030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF672030.out")

meaF772030 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF772030.out")

# %%
mea2040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\mea2040.out")

meaFQ2040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaFQ2040.out")

meaQ2040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaQ2040.out")

meaF12040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF12040.out")

meaF22040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF22040.out")

meaF32040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF32040.out")

meaF452040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF452040.out")

meaF672040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF672040.out")

meaF772040 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF772040.out")

# %%
mea2050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\mea2050.out")

meaFQ2050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaFQ2050.out")

meaQ2050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaQ2050.out")

meaF12050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF12050.out")

meaF22050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF22050.out")

meaF32050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF32050.out")

meaF452050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF452050.out")

meaF672050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF672050.out")

meaF772050 = np.loadtxt("C:\\Users\\DELL\\Documents\\SWMTframework\\meaF772050.out")

# %%
data=xr.open_dataset("D:\\ihespdata\\B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.2010-08.WMF.nc")
A = data.sigma_wmt

# %%
fig = plt.figure(figsize=(20,30), dpi=100)
#ax0 = fig.add_axes([0.1, 0.1, 0.8, 0.36],
                    #xticklabels=[])
ax = plt.subplot(3, 2, 1)
my_font = {'fontname':'Cambria', 'size':'15'}
#############################################
##width = 2500000,height = 1500000
##lat_0 = -65, lon_0 = 0
#############################################
ax.plot(mea2010,A,color = 'k',linestyle = '-', linewidth = 2, label = 'ALL (SFWF-QFLUX)')
ax.plot(meaQ2010,A,color = 'red',linestyle = '--', linewidth = 2, label = 'Heat flux')
ax.plot(meaFQ2010-meaQ2010,A,color = 'purple',linestyle = '--', linewidth = 2, label = 'Freshwater flux')
ax.plot(meaF12010+meaF22010,A,color = 'g',linestyle = ':', linewidth = 2, label = 'PREC_F+EVAP_F (P-E)')
#ax.plot(meaF22010,A,color = 'orange',linestyle = ':', linewidth = 2, label = 'EVAP_F')
ax.plot(meaF32010+meaF772010,A,color = 'purple',linestyle = ':', linewidth = 2, label = 'ROFF_F+IOFF_F (Land runoff)')
ax.plot(meaF452010+meaF672010,A,color = 'blue',linestyle = ':', linewidth = 2, label = 'MELT_F+SALT_F-QFLUX (Sea ice)')
#ax.plot(meaF672010,A,color = 'black',linestyle = ':', linewidth = 2, label = '-QFLUX (ocean component model)')
    #ax.plot(meaF[0,:],A,color = 'red',linestyle = ':', linewidth = 2, label = 'Freshflux')
    #ax.plot(meaF[6,:],A,color = 'darkred',linestyle = '--', linewidth = 2, label = 'Frazil ice')
    #ax.plot(IOFF,A,color = 'darkred',linestyle = '-', linewidth = 2, label = 'ice   runoff  flux due to land-model snow capping')
ax.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 15)
#ax.set_xlabel('Surface water mass transformation (Sv) for only Antarctica shelf part (depth<1000m)', fontsize = 20)
ax.text(6.6,32.73, 'DSW', fontsize = 20, color = 'purple')
ax.text(6.6,32.50, 'CDW', fontsize = 20, color = 'tomato')    
ax.text(6.6,32.3, 'AASW', fontsize = 20, color = 'royalblue') 
ax.plot([0,0],[31,33],'k',linewidth=0.5)
ax.set_xticks([-2,0,2,4,6,8])
ax.set_xticklabels(['-2','0','2','4','6','8'], fontsize = 18)
ax.set_yticks([31,31.25,31.5,31.75,32,32.25,32.5,32.75,33])
ax.set_yticklabels(['31','31.25','31.5','31.75','32','32.25','32.5','32.75','33'], fontsize = 18)
ax.set_xlim((-3,8))
ax.set_ylim((33.0,31.0))
ax.plot([-37,13],[32.57, 32.57],'darkred',linewidth=3)
ax.plot([-37,13],[32.37, 32.37],'grey',linewidth=3)
ax.set_title( '2010 yearly-mean', fontsize = 18, color = 'darkred')
ax.set_xlabel('Surface water mass transformation on Antarctica shelf(depth<1000m, Sv)', fontsize = 15)
ax.text(0.02, 0.05, '(a)', transform=ax.transAxes,size=50, weight='bold')
ax.legend(fontsize = 12) 
#############################################################################################
ax = plt.subplot(3, 2, 2)
my_font = {'fontname':'Cambria', 'size':'15'}
#############################################
##width = 2500000,height = 1500000
##lat_0 = -65, lon_0 = 0
#############################################
ax.plot(mea2020,A,color = 'k',linestyle = '-', linewidth = 2, label = 'ALL (SFWF-QFLUX)')
ax.plot(meaQ2020,A,color = 'red',linestyle = '--', linewidth = 2, label = 'Heat flux')
ax.plot(meaFQ2020-meaQ2020,A,color = 'purple',linestyle = '--', linewidth = 2, label = 'Freshwater flux')
ax.plot(meaF12020+meaF22020,A,color = 'g',linestyle = ':', linewidth = 2, label = 'PREC_F+EVAP_F (P-E)')
#ax.plot(meaF22020,A,color = 'orange',linestyle = ':', linewidth = 2, label = 'EVAP_F')
ax.plot(meaF32020+meaF772020,A,color = 'purple',linestyle = ':', linewidth = 2, label = 'ROFF_F+IOFF_F (Land runoff)')
ax.plot(meaF452020+meaF672020,A,color = 'blue',linestyle = ':', linewidth = 2, label = 'MELT_F+SALT_F-QFLUX (Sea ice)')
#ax.plot(meaF672020,A,color = 'black',linestyle = ':', linewidth = 2, label = '-QFLUX (ocean component model)')
    #ax.plot(meaF[6,:],A,color = 'darkred',linestyle = '--', linewidth = 2, label = 'Frazil ice')
    #ax.plot(IOFF,A,color = 'darkred',linestyle = '-', linewidth = 2, label = 'ice   runoff  flux due to land-model snow capping')
#ax.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 15)
#ax.set_xlabel('Surface water mass transformation (Sv) for only Antarctica shelf part (depth<1000m)', fontsize = 20)
ax.plot([0,0],[31,33],'k',linewidth=0.5)
ax.set_xticks([-2,0,2,4,6,8])
ax.set_xticklabels(['-2','0','2','4','6','8'], fontsize = 18)
#ax.set_yticks([31,31.25,31.5,31.75,32,32.25,32.5,32.75,33])
ax.set_yticklabels([], fontsize = 18)
ax.set_xlim((-3,8))
ax.set_ylim((33.0,31.0))
ax.plot([-37,13],[32.57, 32.57],'darkred',linewidth=3)
ax.plot([-37,13],[32.37, 32.37],'grey',linewidth=3)
ax.set_title( '2020 yearly-mean', fontsize = 18, color = 'darkred')
ax.set_xlabel('Surface water mass transformation on Antarctica shelf(depth<1000m, Sv)', fontsize = 15)
ax.legend(fontsize = 12) 
ax.text(6.6,32.73, 'DSW', fontsize = 20, color = 'purple')
ax.text(7,32.50, 'CDW', fontsize = 20, color = 'tomato')    
ax.text(6.6,32.3, 'AASW', fontsize = 20, color = 'royalblue')
ax.text(0.02, 0.05, '(b)', transform=ax.transAxes,size=50, weight='bold')
#############################################################################################
ax = plt.subplot(3, 2, 3)
my_font = {'fontname':'Cambria', 'size':'15'}
#############################################
##width = 2500000,height = 1500000
##lat_0 = -65, lon_0 = 0
#############################################
ax.plot(mea2030,A,color = 'k',linestyle = '-', linewidth = 2, label = 'ALL (SFWF-QFLUX)')
ax.plot(meaQ2030,A,color = 'red',linestyle = '--', linewidth = 2, label = 'Heat flux')
ax.plot(meaFQ2030-meaQ2030,A,color = 'purple',linestyle = '--', linewidth = 2, label = 'Freshwater flux')
ax.plot(meaF12030+meaF22030,A,color = 'g',linestyle = ':', linewidth = 2, label = 'PREC_F+EVAP_F (P-E)')
#ax.plot(meaF22030,A,color = 'orange',linestyle = ':', linewidth = 2, label = 'EVAP_F')
ax.plot(meaF32030+meaF772030,A,color = 'purple',linestyle = ':', linewidth = 2, label = 'ROFF_F+IOFF_F (Land runoff)')
ax.plot(meaF452030+meaF672030,A,color = 'blue',linestyle = ':', linewidth = 2, label = 'MELT_F+SALT_F-QFLUX (Sea ice)')
#ax.plot(meaF672030,A,color = 'black',linestyle = ':', linewidth = 2, label = '-QFLUX (ocean component model)')
ax.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 15)
#ax.set_xlabel('Surface water mass transformation (Sv) for only Antarctica shelf part (depth<1000m)', fontsize = 20)
ax.plot([0,0],[31,33],'k',linewidth=0.5)
ax.set_xticks([-2,0,2,4,6,8])
ax.set_xticklabels(['-2','0','2','4','6','8'], fontsize = 18)
ax.set_yticks([31,31.25,31.5,31.75,32,32.25,32.5,32.75,33])
ax.set_yticklabels(['31','31.25','31.5','31.75','32','32.25','32.5','32.75','33'], fontsize = 18)
ax.set_xlim((-3,8))
ax.set_ylim((33.0,31.0))
ax.plot([-37,13],[32.57, 32.57],'darkred',linewidth=3)
ax.plot([-37,13],[32.37, 32.37],'grey',linewidth=3)
ax.set_title( '2030 yearly-mean', fontsize = 18, color = 'darkred')
ax.set_xlabel('Surface water mass transformation on Antarctica shelf(depth<1000m, Sv)', fontsize = 15)
ax.text(0.02, 0.05, '(c)', transform=ax.transAxes,size=50, weight='bold')
ax.text(6.6,32.73, 'DSW', fontsize = 20, color = 'purple')
ax.text(6.6,32.50, 'CDW', fontsize = 20, color = 'tomato')    
ax.text(6.6,32.3, 'AASW', fontsize = 20, color = 'royalblue')
ax.legend(fontsize = 12) 
#############################################################################################
ax = plt.subplot(3, 2, 4)
my_font = {'fontname':'Cambria', 'size':'15'}
#############################################
##width = 2500000,height = 1500000
##lat_0 = -65, lon_0 = 0
#############################################
ax.plot(mea2040,A,color = 'k',linestyle = '-', linewidth = 2, label = 'ALL (SFWF-QFLUX)')
ax.plot(meaQ2040,A,color = 'red',linestyle = '--', linewidth = 2, label = 'Heat flux')
ax.plot(meaFQ2040-meaQ2040,A,color = 'purple',linestyle = '--', linewidth = 2, label = 'Freshwater flux')
ax.plot(meaF12040+meaF22040,A,color = 'g',linestyle = ':', linewidth = 2, label = 'PREC_F+EVAP_F (P-E)')
#ax.plot(meaF22040,A,color = 'orange',linestyle = ':', linewidth = 2, label = 'EVAP_F')
ax.plot(meaF32040+meaF772040,A,color = 'purple',linestyle = ':', linewidth = 2, label = 'ROFF_F+IOFF_F (Land runoff)')
ax.plot(meaF452040+meaF672040,A,color = 'blue',linestyle = ':', linewidth = 2, label = 'MELT_F+SALT_F-QFLUX (Sea ice)')
#ax.plot(meaF672040,A,color = 'black',linestyle = ':', linewidth = 2, label = '-QFLUX (ocean component model)')
#ax.plot(meaF672040,A,color = 'black',linestyle = ':', linewidth = 2, label = 'Residual term')
    #ax.plot(meaF[6,:],A,color = 'darkred',linestyle = '--', linewidth = 2, label = 'Frazil ice')
    #ax.plot(IOFF,A,color = 'darkred',linestyle = '-', linewidth = 2, label = 'ice   runoff  flux due to land-model snow capping')
#ax.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 15)
#ax.set_xlabel('Surface water mass transformation (Sv) for only Antarctica shelf part (depth<1000m)', fontsize = 20)
ax.plot([0,0],[31,33],'k',linewidth=0.5)
ax.set_xticks([-2,0,2,4,6,8])
ax.set_xticklabels(['-2','0','2','4','6','8'], fontsize = 18)
#ax.set_yticks([31,31.25,31.5,31.75,32,32.25,32.5,32.75,33])
ax.set_yticklabels([], fontsize = 18)
ax.set_xlim((-3,8))
ax.set_ylim((33.0,31.0))
ax.plot([-37,13],[32.57, 32.57],'darkred',linewidth=3)
ax.plot([-37,13],[32.37, 32.37],'grey',linewidth=3)
ax.set_title( '2040 yearly-mean', fontsize = 18, color = 'darkred')
ax.legend(fontsize = 12) 
ax.set_xlabel('Surface water mass transformation on Antarctica shelf(depth<1000m, Sv)', fontsize = 15)
ax.text(0.02, 0.05, '(d)', transform=ax.transAxes,size=50, weight='bold')

ax.text(6.6,32.73, 'DSW', fontsize = 20, color = 'purple')
ax.text(6.6,32.50, 'CDW', fontsize = 20, color = 'tomato')    
ax.text(6.6,32.3, 'AASW', fontsize = 20, color = 'royalblue')
#############################################################################################
ax = plt.subplot(3, 2, 5)
my_font = {'fontname':'Cambria', 'size':'15'}
#############################################
##width = 2500000,height = 1500000
##lat_0 = -65, lon_0 = 0
#############################################
ax.plot(mea2050,A,color = 'k',linestyle = '-', linewidth = 2, label = 'ALL (SFWF-QFLUX)')
ax.plot(meaQ2050,A,color = 'red',linestyle = '--', linewidth = 2, label = 'Heat flux')
ax.plot(meaFQ2050-meaQ2050,A,color = 'purple',linestyle = '--', linewidth = 2, label = 'Freshwater flux')
ax.plot(meaF12050+meaF22050,A,color = 'g',linestyle = ':', linewidth = 2, label = 'PREC_F+EVAP_F (P-E)')
#ax.plot(meaF22050,A,color = 'orange',linestyle = ':', linewidth = 2, label = 'EVAP_F')
ax.plot(meaF32050+meaF772050,A,color = 'purple',linestyle = ':', linewidth = 2, label = 'ROFF_F+IOFF_F (Land runoff)')
ax.plot(meaF452050+meaF672050,A,color = 'blue',linestyle = ':', linewidth = 2, label = 'MELT_F+SALT_F-QFLUX (Sea ice)')
#ax.plot(meaF672050,A,color = 'black',linestyle = ':', linewidth = 2, label = '-QFLUX (ocean component model)')
#ax.plot(meaF672050,A,color = 'black',linestyle = ':', linewidth = 2, label = 'Residual term')
ax.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 15)
#ax.set_xlabel('Surface water mass transformation (Sv) for only Antarctica shelf part (depth<1000m)', fontsize = 20)
ax.plot([0,0],[31,33],'k',linewidth=0.5)
ax.set_xticks([-2,0,2,4,6,8])
ax.set_xticklabels(['-2','0','2','4','6','8'], fontsize = 18)
ax.set_yticks([31,31.25,31.5,31.75,32,32.25,32.5,32.75,33])
ax.set_yticklabels(['31','31.25','31.5','31.75','32','32.25','32.5','32.75','33'], fontsize = 18)
ax.set_xlim((-3,8))
ax.set_ylim((33.0,31.0))
ax.plot([-37,13],[32.57, 32.57],'darkred',linewidth=3)
ax.plot([-37,13],[32.37, 32.37],'grey',linewidth=3)
ax.set_title( '2050 yearly-mean', fontsize = 18, color = 'darkred')
ax.set_xlabel('Surface water mass transformation on Antarctica shelf(depth<1000m, Sv)', fontsize = 15)
ax.legend(fontsize = 12,loc='upper right') 
ax.text(0.02, 0.05, '(e)', transform=ax.transAxes,size=50, weight='bold')

ax.text(6.6,32.73, 'DSW', fontsize = 20, color = 'purple')
ax.text(6.6,32.50, 'CDW', fontsize = 20, color = 'tomato')    
ax.text(6.6,32.3, 'AASW', fontsize = 20, color = 'royalblue')
#############################################################################################
ax = plt.subplot(3, 2, 6)
my_font = {'fontname':'Cambria', 'size':'15'}
#############################################
##width = 2500000,height = 1500000
##lat_0 = -65, lon_0 = 0
#############################################
ax.plot(mea2060,A,color = 'k',linestyle = '-', linewidth = 2, label = 'ALL (SFWF-QFLUX)')
ax.plot(meaQ2060,A,color = 'red',linestyle = '--', linewidth = 2, label = 'Heat flux')
ax.plot(meaFQ2060-meaQ2060,A,color = 'purple',linestyle = '--', linewidth = 2, label = 'Freshwater flux')
ax.plot(meaF12060+meaF22060,A,color = 'g',linestyle = ':', linewidth = 2, label = 'PREC_F+EVAP_F (P-E)')
#ax.plot(meaF22060,A,color = 'orange',linestyle = ':', linewidth = 2, label = 'EVAP_F')
ax.plot(meaF32060+meaF772060,A,color = 'purple',linestyle = ':', linewidth = 2, label = 'ROFF_F+IOFF_F (Land runoff)')
ax.plot(meaF452060+meaF672060,A,color = 'blue',linestyle = ':', linewidth = 2, label = 'MELT_F+SALT_F-QFLUX (Sea ice)')
#ax.plot(meaF12060+meaF22060+meaF32060+meaF772060+meaF452060+meaF672060,A,color = 'yellow',linestyle = ':', linewidth = 2, label = '-QFLUX (ocean component model)')
#ax.plot(meaF672060,A,color = 'black',linestyle = ':', linewidth = 2, label = 'Residual term')
    #ax.plot(meaF[6,:],A,color = 'darkred',linestyle = '--', linewidth = 2, label = 'Frazil ice')
    #ax.plot(IOFF,A,color = 'darkred',linestyle = '-', linewidth = 2, label = 'ice   runoff  flux due to land-model snow capping')
#ax.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 15)
ax.set_xlabel('Surface water mass transformation on Antarctica shelf(depth<1000m, Sv)', fontsize = 15)
ax.plot([0,0],[31,33],'k',linewidth=0.5)
ax.set_xticks([-2,0,2,4,6,8])
ax.set_xticklabels(['-2','0','2','4','6','8'], fontsize = 18)
#ax.set_yticks([31,31.25,31.5,31.75,32,32.25,32.5,32.75,33])
ax.set_yticklabels([], fontsize = 18)
ax.set_xlim((-3,8))
ax.set_ylim((33.0,31.0))
ax.plot([-37,13],[32.57, 32.57],'darkred',linewidth=3)
ax.plot([-37,13],[32.37, 32.37],'grey',linewidth=3)
ax.set_title( '2060 yearly-mean', fontsize = 18, color = 'darkred')
ax.legend(fontsize = 12,loc='upper right') 
ax.text(0.02, 0.05, '(f)', transform=ax.transAxes,size=50, weight='bold')

ax.text(6.6,32.73, 'DSW', fontsize = 20, color = 'purple')
ax.text(6.6,32.50, 'CDW', fontsize = 20, color = 'tomato')    
ax.text(6.6,32.3, 'AASW', fontsize = 20, color = 'royalblue')
#############################################################################################
plt.savefig("WMTall.png",bbox_inches='tight')

# %%
ax.plot(mea2060,A,color = 'k',linestyle = '-', linewidth = 2, label = 'ALL (SFWF-QFLUX)')
ax.plot(meaQ2060,A,color = 'red',linestyle = '--', linewidth = 2, label = 'Heat flux')
ax.plot(meaFQ2060-meaQ2060,A,color = 'purple',linestyle = '--', linewidth = 2, label = 'Freshwater flux')
ax.plot(meaF12060+meaF22060,A,color = 'g',linestyle = ':', linewidth = 2, label = 'PREC_F+EVAP_F (atmosphere component model)')
#ax.plot(meaF22060,A,color = 'orange',linestyle = ':', linewidth = 2, label = 'EVAP_F')
ax.plot(meaF32060+meaF772060,A,color = 'purple',linestyle = ':', linewidth = 2, label = 'ROFF_F+IOFF_F (land component model)')
ax.plot(meaF452060,A,color = 'blue',linestyle = ':', linewidth = 2, label = 'MELT_F+SALT_F (sea ice component model)')
ax.plot(meaF672060,A,color = 'black',linestyle = ':', linewidth = 2, label = '-QFLUX (ocean component model)')
