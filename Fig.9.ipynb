# %%
import netCDF4 as nc
from pathlib import Path
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib as mpl
import matplotlib.path as mpath
import cartopy.feature as cfeature
import cmocean
import cftime
import copy
import scipy.stats
from scipy import signal

# %matplotlib inline

# %%
data=xr.open_dataset("D:\\newdata\\B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.2010-08.WMF2000.nc")
A = data.sigma_wmt

# %%
###### loading and computations for isobath transport ##########
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
net_offshore10off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2010_2000off.nc')
## load experiment + take mean in time
net_offshore20off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2020_2000off.nc')
## load experiment + take mean in time
net_offshore30off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2030_2000off.nc')
## load experiment + take mean in time
net_offshore40off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2040_2000off.nc')
## load experiment + take mean in time
net_offshore50off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2050_2000off.nc')
## load experiment + take mean in time
net_offshore60off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2060_2000off.nc')
## load experiment + take mean in time
net_offshore70off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2070_2000off.nc')
## load experiment + take mean in time
net_offshore80off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2080_2000off.nc')
## load experiment + take mean in time
## load experiment + take mean in time
net_offshore90off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2090_2000off.nc')
################
net_offshore2100off =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2100_2000off.nc')
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
#net_offshore1850 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_1850.nc')

# %%
###### loading and computations for isobath transport ##########
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
net_offshore10all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2010_2000all.nc')
## load experiment + take mean in time
net_offshore20all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2020_2000all.nc')
## load experiment + take mean in time
net_offshore30all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2030_2000all.nc')
## load experiment + take mean in time
net_offshore40all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2040_2000all.nc')
## load experiment + take mean in time
net_offshore50all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2050_2000all.nc')
## load experiment + take mean in time
net_offshore60all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2060_2000all.nc')
## load experiment + take mean in time
net_offshore70all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2070_2000all.nc')
## load experiment + take mean in time
net_offshore80all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2080_2000all.nc')
## load experiment + take mean in time
## load experiment + take mean in time
net_offshore90all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2090_2000all.nc')
################
net_offshore2100all =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2100_2000all.nc')
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
#net_offshore1850 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_1850.nc')

# %%
###### loading and computations for isobath transport ##########
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
net_offshore10 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2010_2000.nc')
## load experiment + take mean in time
net_offshore20 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2020_2000.nc')
## load experiment + take mean in time
net_offshore30 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2030_2000.nc')
## load experiment + take mean in time
net_offshore40 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2040_2000.nc')
## load experiment + take mean in time
net_offshore50 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2050_2000.nc')
## load experiment + take mean in time
net_offshore60 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2060_2000.nc')
## load experiment + take mean in time
net_offshore70 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2070_2000.nc')
## load experiment + take mean in time
net_offshore80 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2080_2000.nc')
## load experiment + take mean in time
## load experiment + take mean in time
net_offshore90 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2090_2000.nc')
################
net_offshore2100 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_2100_2000.nc')
## load control + take mean in time (control year 5 and 10 tested and pretty much identical)
#net_offshore1850 =  xr.open_dataset('C:\\Users\\DELL\\Documents\\newplots\\mea_binned_1850.nc')

# %%
fontsize=24

fig = plt.figure(figsize=(36, 36))



ax7b = fig.add_axes([0.5, 0.32, 0.37, 0.12])

ax7c = fig.add_axes([0.5, 0.443, 0.37, 0.05])

ax7a = fig.add_axes([0.5, 0.496, 0.37, 0.12])

#ax7a.set_title(r'Surface water mass transformation open ocean (Sv)',fontsize=fontsize, loc='left')

ax7a.plot(net_offshore10off.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7a.plot(net_offshore20off.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7a.plot(net_offshore30off.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7a.plot(net_offshore40off.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7a.plot(net_offshore50off.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7a.plot(net_offshore60off.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7a.plot(net_offshore70off.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7a.plot(net_offshore80off.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7a.plot(net_offshore90off.mea,A ,color = 'darkred', linestyle = '-.',linewidth = 2, label = '2090')
ax7a.plot(net_offshore2100off.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7a.plot([0,0],[35,38],'k',linewidth=0.5)

#ax7a.text(-14,36.2, 'Upper Cell', fontsize = 28, color = 'purple')
#ax7a.text(13,36.2, 'AAIW', fontsize = 28, color = 'royalblue')
#ax7a.set_ylabel(r'$\sigma_2\; (kg/m^{3})$',loc='bottom')
#ax7a.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 28,loc='bottom')
ax7a.set_xticklabels([])
ax7a.set_xticks([])         

ax7a.set_yticks([35.0,35.2,35.4,35.6,35.8,36.0,36.2,36.4,36.6,36.8])
ax7a.set_yticklabels(['35.0','35.2','35.4','35.6','35.8','36.0','36.2','36.4','36.6','36.8'], fontsize = 28)

ax7a.set_ylim((37, 36))
ax7a.set_xlim((-34, 18))
################################################################################################################

ax7c.plot(net_offshore10off.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7c.plot(net_offshore20off.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7c.plot(net_offshore30off.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7c.plot(net_offshore40off.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7c.plot(net_offshore50off.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7c.plot(net_offshore60off.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7c.plot(net_offshore70off.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7c.plot(net_offshore80off.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7c.plot(net_offshore90off.mea,A ,color = 'darkred', linestyle = '-.', linewidth = 2,label = '2090')
ax7c.plot(net_offshore2100off.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7c.set_ylim(37.25, 37)
ax7c.set_xlim(-34, 18)

ax7c.plot([0,0],[35,38],'k',linewidth=0.5)
ax7c.set_xticklabels([])
ax7c.set_xticks([])         

ax7c.set_yticks([37.0,37.1,37.2])
ax7c.set_yticklabels(['37.0','37.1','37.2'], fontsize = 28)
#ax7c.text(-14,37.15, 'CDW layer', fontsize = 28, color = 'red')
#ax7c.text(13,37.05, 'UCDW', fontsize = 28, color = 'tomato')
#ax7c.text(13,37.23, 'LCDW', fontsize = 28, color = 'darkred')
#ax7c.text(13.6,32.78, 'AABW', fontsize = 28, color = 'purple')

ax7c.set_ylabel(r'$\sigma_{2}$ (kg m$^{-3}$)', fontsize = 18,loc='center')



#############################################################################################################################
ax7b.plot(net_offshore10off.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7b.plot(net_offshore20off.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7b.plot(net_offshore30off.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7b.plot(net_offshore40off.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7b.plot(net_offshore50off.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7b.plot(net_offshore60off.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7b.plot(net_offshore70off.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7b.plot(net_offshore80off.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7b.plot(net_offshore90off.mea,A ,color = 'darkred', linestyle = '-.', linewidth = 2,label = '2090')
ax7b.plot(net_offshore2100off.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7b.set_ylim(37.6, 37.25)
ax7b.set_xlim(-34, 18)
#ax7b.set_xlabel('For only open-ocean part (Sv, 80$^\circ$S - 30$^\circ$S, depth > 1000m)', fontsize = 28)
ax7b.plot([0,0],[35,38],'k',linewidth=0.5)
ax7b.set_yticks([37.25,37.3,37.4,37.5,37.6])
ax7b.set_yticklabels(['37.25','37.3','37.4','37.5','37.6'], fontsize = 28)
ax7b.set_xticks([-30,-20,-10,0,5,10,15])
ax7b.set_xticklabels([], fontsize = 28)
ax7b.plot([-37,18],[37.41, 37.41], 'grey',linestyle = '-.',linewidth=1)
#ax7b.legend(fontsize = 16,loc='lower left')
#ax.text(-23.6,32.2, 'Upper Cell', fontsize = 28, color = 'tomato')
#ax7b.text(-14,37.35, 'Lower Cell', fontsize = 28, color = 'darkred')
#ax7b.text(13,37.35, 'AABW', fontsize = 28, color = 'black')
#ax7b.text(13,37.57, '(b)', fontsize = 60, color = 'black')
#ax7b.set_yticks([37.25,37.0,36.75,36.5])
#ax7b.set_yticklabels(['37.25','37.0','36.75',''])
#ax7b.plot([55,55],[37.0,37.25],c='k')
#############################################################################################################################
ax7b = fig.add_axes([0.5, 0.00, 0.37, 0.12])

ax7c = fig.add_axes([0.5, 0.123, 0.37, 0.05])

ax7a = fig.add_axes([0.5, 0.176, 0.37, 0.12])


#ax7a.set_title(r'Surface water mass transformation open ocean (Sv)',fontsize=fontsize, loc='left')

ax7a.plot(net_offshore10.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7a.plot(net_offshore20.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7a.plot(net_offshore30.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7a.plot(net_offshore40.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7a.plot(net_offshore50.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7a.plot(net_offshore60.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7a.plot(net_offshore70.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7a.plot(net_offshore80.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7a.plot(net_offshore90.mea,A ,color = 'darkred', linestyle = '-.',linewidth = 2, label = '2090')
ax7a.plot(net_offshore2100.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7a.plot([0,0],[35,38],'k',linewidth=0.5)

#ax7a.text(-14,36.2, 'Upper Cell', fontsize = 28, color = 'purple')
#ax7a.text(13,36.2, 'AAIW', fontsize = 28, color = 'royalblue')
#ax7a.set_ylabel(r'$\sigma_2\; (kg/m^{3})$',loc='bottom')
#ax7a.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 28,loc='bottom')
ax7a.set_xticklabels([])
ax7a.set_xticks([])         

ax7a.set_yticks([35.0,35.2,35.4,35.6,35.8,36.0,36.2,36.4,36.6,36.8])
ax7a.set_yticklabels(['35.0','35.2','35.4','35.6','35.8','36.0','36.2','36.4','36.6','36.8'], fontsize = 28)
ax7a.set_ylim((37, 36))
ax7a.set_xlim((-34, 18))


################################################################################################################

ax7c.plot(net_offshore10.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7c.plot(net_offshore20.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7c.plot(net_offshore30.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7c.plot(net_offshore40.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7c.plot(net_offshore50.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7c.plot(net_offshore60.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7c.plot(net_offshore70.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7c.plot(net_offshore80.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7c.plot(net_offshore90.mea,A ,color = 'darkred', linestyle = '-.', linewidth = 2,label = '2090')
ax7c.plot(net_offshore2100.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7c.set_ylim(37.25, 37)
ax7c.set_xlim(-34, 18)

ax7c.plot([0,0],[35,38],'k',linewidth=0.5)
ax7c.set_xticklabels([])
ax7c.set_xticks([])         

ax7c.set_yticks([37.0,37.1,37.2])
ax7c.set_yticklabels(['37.0','37.1','37.2'], fontsize = 28)
#ax7c.text(-14,37.15, 'CDW layer', fontsize = 28, color = 'red')
#ax7c.text(13,37.05, 'UCDW', fontsize = 28, color = 'tomato')
#ax7c.text(13,37.23, 'LCDW', fontsize = 28, color = 'darkred')
#ax7c.text(13.6,32.78, 'AABW', fontsize = 28, color = 'purple')

ax7c.set_ylabel(r'$\sigma_{2}$ (kg m$^{-3}$)', fontsize = 18,loc='center')



#############################################################################################################################
ax7b.plot(net_offshore10.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7b.plot(net_offshore20.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7b.plot(net_offshore30.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7b.plot(net_offshore40.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7b.plot(net_offshore50.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7b.plot(net_offshore60.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7b.plot(net_offshore70.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7b.plot(net_offshore80.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7b.plot(net_offshore90.mea,A ,color = 'darkred', linestyle = '-.', linewidth = 2,label = '2090')
ax7b.plot(net_offshore2100.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7b.set_ylim(37.6, 37.25)
ax7b.set_xlim(-34, 18)
#ax7b.set_xlabel('For only Antarctica shelf part (Sv, 80$^\circ$S - 30$^\circ$S, depth<1000m)', fontsize = 28)
ax7b.plot([0,0],[35,38],'k',linewidth=0.5)
ax7b.set_yticks([37.25,37.3,37.4,37.5,37.6])
ax7b.set_yticklabels(['37.25','37.3','37.4','37.5','37.6'], fontsize = 28)
ax7b.set_xticks([-30,-20,-10,0,5,10,15])
ax7b.set_xticklabels(['-30','-20','-10','0','5','10','15'], fontsize = 28)
ax7b.plot([-37,18],[37.41, 37.41], 'grey',linestyle = '-.',linewidth=1)
ax7b.legend(fontsize = 16,loc='lower left')
#ax.text(-23.6,32.2, 'Upper Cell', fontsize = 28, color = 'tomato')
#ax7b.text(-14,37.35, 'Lower Cell', fontsize = 28, color = 'darkred')
#ax7b.text(13,37.35, 'AABW', fontsize = 28, color = 'black')
#ax7b.text(13,37.57, '(a)', fontsize = 40, color = 'black')
#############################################################################################################################
ax7b.text(13,37.57, '(c)', fontsize = 60, color = 'black')
#ax7b.set_yticks([37.25,37.0,36.75,36.5])
#ax7b.set_yticklabels(['37.25','37.0','36.75',''])
#ax7b.plot([55,55],[37.0,37.25],c='k')
#############################################################################################################################



ax7b = fig.add_axes([0.5, 0.64, 0.37, 0.12])

ax7c = fig.add_axes([0.5, 0.763, 0.37, 0.05])

ax7a = fig.add_axes([0.5, 0.816, 0.37, 0.12])
#ax7a.set_title(r'Surface water mass transformation open ocean (Sv)',fontsize=fontsize, loc='left')

ax7a.plot(net_offshore10all.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7a.plot(net_offshore20all.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7a.plot(net_offshore30all.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7a.plot(net_offshore40all.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7a.plot(net_offshore50all.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7a.plot(net_offshore60all.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7a.plot(net_offshore70all.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7a.plot(net_offshore80all.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7a.plot(net_offshore90all.mea,A ,color = 'darkred', linestyle = '-.',linewidth = 2, label = '2090')
ax7a.plot(net_offshore2100all.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7a.plot([0,0],[35,38],'k',linewidth=0.5)

#ax7a.text(-14,36.2, 'Upper Cell', fontsize = 28, color = 'purple')
#ax7a.text(13,36.2, 'AAIW', fontsize = 28, color = 'royalblue')
#ax7a.set_ylabel(r'$\sigma_2\; (kg/m^{3})$',loc='bottom')
#ax7a.set_ylabel(r'$\sigma_{1}$ (kg m$^{-3}$)', fontsize = 28,loc='bottom')
ax7a.set_xticklabels([])
ax7a.set_xticks([])         

ax7a.set_yticks([35.0,35.2,35.4,35.6,35.8,36.0,36.2,36.4,36.6,36.8])
ax7a.set_yticklabels(['35.0','35.2','35.4','35.6','35.8','36.0','36.2','36.4','36.6','36.8'], fontsize = 28)
ax7a.set_ylim((37, 36))
ax7a.set_xlim((-34, 18))


################################################################################################################

ax7c.plot(net_offshore10all.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7c.plot(net_offshore20all.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7c.plot(net_offshore30all.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7c.plot(net_offshore40all.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7c.plot(net_offshore50all.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7c.plot(net_offshore60all.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7c.plot(net_offshore70all.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7c.plot(net_offshore80all.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7c.plot(net_offshore90all.mea,A ,color = 'darkred', linestyle = '-.', linewidth = 2,label = '2090')
ax7c.plot(net_offshore2100all.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7c.set_ylim(37.25, 37)
ax7c.set_xlim(-34, 18)

ax7c.plot([0,0],[35,38],'k',linewidth=0.5)
ax7c.set_xticklabels([])
ax7c.set_xticks([])         

ax7c.set_yticks([37.0,37.1,37.2])
ax7c.set_yticklabels(['37.0','37.1','37.2'], fontsize = 28)
#ax7c.text(-14,37.15, 'CDW layer', fontsize = 28, color = 'red')
#ax7c.text(13,37.05, 'UCDW', fontsize = 28, color = 'tomato')
#ax7c.text(13,37.23, 'LCDW', fontsize = 28, color = 'darkred')
#ax7c.text(13.6,32.78, 'AABW', fontsize = 28, color = 'purple')

ax7c.set_ylabel(r'$\sigma_{2}$ (kg m$^{-3}$)', fontsize = 18,loc='center')



#############################################################################################################################
ax7b.plot(net_offshore10all.mea,A ,color = 'k', linewidth = 2, label = '2010')
ax7b.plot(net_offshore20all.mea,A , color = 'darkred', linewidth = 2, label = '2020')
ax7b.plot(net_offshore30all.mea,A ,color = 'darkgreen', linewidth = 2, label = '2030')
ax7b.plot(net_offshore40all.mea,A ,color = 'red', linestyle = '--', linewidth = 2, label = '2040')
ax7b.plot(net_offshore50all.mea,A ,color ='purple',linestyle = '--',linewidth = 2, label = '2050')
ax7b.plot(net_offshore60all.mea,A ,color = 'darkgreen', linestyle = '--', linewidth = 2, label = '2060')
ax7b.plot(net_offshore70all.mea,A ,color = 'darkblue', linestyle = '-.', linewidth = 2, label = '2070')
ax7b.plot(net_offshore80all.mea,A ,color = 'blue', linestyle = '-.',linewidth = 2, label = '2080')
ax7b.plot(net_offshore90all.mea,A ,color = 'darkred', linestyle = '-.', linewidth = 2,label = '2090')
ax7b.plot(net_offshore2100all.mea,A ,color = 'orange', linestyle = '-.',linewidth = 2, label = '2100')

ax7b.set_ylim(37.6, 37.25)
ax7b.set_xlim(-34, 18)
#ax7b.set_xlabel('Surface water mass transformation (Sv) for all Southern Ocean (80$^\circ$S - 30$^\circ$S)', fontsize = 28)
ax7b.plot([0,0],[35,38],'k',linewidth=0.5)
ax7b.set_yticks([37.25,37.3,37.4,37.5,37.6])
ax7b.set_yticklabels(['37.25','37.3','37.4','37.5','37.6'], fontsize = 28)
ax7b.set_xticks([-30,-20,-10,0,5,10,15])
ax7b.set_xticklabels([], fontsize = 28)
ax7b.plot([-37,18],[37.41, 37.41], 'grey',linestyle = '-.',linewidth=1)
#ax7b.legend(fontsize = 16,loc='lower left')
#ax.text(-23.6,32.2, 'Upper Cell', fontsize = 28, color = 'tomato')
#ax7b.text(-14,37.35, 'Lower Cell', fontsize = 28, color = 'darkred')
#ax7b.text(13,37.35, 'AABW', fontsize = 28, color = 'black')
ax7b.text(13,37.57, '(a)', fontsize = 60, color = 'black')
#ax7b.set_yticks([37.25,37.0,36.75,36.5])
#ax7b.set_yticklabels(['37.25','37.0','36.75',''])
#ax7b.plot([55,55],[37.0,37.25],c='k')
############################################################################################################


plt.savefig("DSWoffshoreaaaa.png",bbox_inches='tight')
